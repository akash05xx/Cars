# %% [markdown]
# # Car Price

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
style.use('seaborn')
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
df = pd.read_csv("CarPrice.csv")

# %%
#head() will display 1st five columns
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
#Tail() will display last 5 columns
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
#info() will give information of our data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
#describe method returns description of the data in the dataframe
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
#dtypes will show all datatypes which the columns belongs
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
#isnull will show all nan values present in the dataset
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
#notnull() will show not null values
df.notnull().sum()
# Out:
# car_ID              205
# symboling           205
# CarName             205
# fueltype            205
# aspiration          205
# doornumber          205
# carbody             205
# drivewheel          205
# enginelocation      205
# wheelbase           205
# carlength           205
# carwidth            205
# carheight           205
# curbweight          205
# enginetype          205
# cylindernumber      205
# enginesize          205
# fuelsystem          205
# boreratio           205
# stroke              205
# compressionratio    205
# horsepower          205
# peakrpm             205
# citympg             205
# highwaympg          205
# price               205
# dtype: int64

# %%
df.shape
# Out:
# (205, 26)

# %%
df.size
# Out:
# 5330

# %%
df.max()
# Out:
# car_ID                    205
# symbol                      3
# CarName             vw rabbit
# fueltype                  gas
# aspiration              turbo
# doorno                    two
# carbody                 wagon
# drivewheel                rwd
# enginelocation           rear
# wheelbase               120.9
# carlength               208.1
# carwidth                 72.3
# carheight                59.8
# curbweight               4066
# enginetype              rotor
# cylindernumber            two
# enginesize                326
# fuelsystem               spfi
# boreratio                3.94
# stroke                   4.17
# compressionratio         23.0
# horsepower                288
# peakrpm                  6600
# citympg                    49
# highwaympg                 54
# price                 45400.0
# dtype: object

# %%
df.min()
# Out:
# car_ID                         1
# symbol                        -2
# CarName             Nissan versa
# fueltype                  diesel
# aspiration                   std
# doorno                      four
# carbody              convertible
# drivewheel                   4wd
# enginelocation             front
# wheelbase                   86.6
# carlength                  141.1
# carwidth                    60.3
# carheight                   47.8
# curbweight                  1488
# enginetype                  dohc
# cylindernumber             eight
# enginesize                    61
# fuelsystem                  1bbl
# boreratio                   2.54
# stroke                      2.07
# compressionratio             7.0
# horsepower                    48
# peakrpm                     4150
# citympg                       13
# highwaympg                    16
# price                     5118.0
# dtype: object

# %%
df.mean()
# Out:
# C:\Users\Akash Shetty\AppData\Local\Temp\ipykernel_5680\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# car_ID                103.000000
# symboling               0.834146
# wheelbase              98.756585
# carlength             174.049268
# carwidth               65.907805
# carheight              53.724878
# curbweight           2555.565854
# enginesize            126.907317
# boreratio               3.329756
# stroke                  3.255415
# compressionratio       10.142537
# horsepower            104.117073
# peakrpm              5125.121951
# citympg                25.219512
# highwaympg             30.751220
# price               13276.710571
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\Akash Shetty\AppData\Local\Temp\ipykernel_5680\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# car_ID                103.00
# symboling               1.00
# wheelbase              97.00
# carlength             173.20
# carwidth               65.50
# carheight              54.10
# curbweight           2414.00
# enginesize            120.00
# boreratio               3.31
# stroke                  3.29
# compressionratio        9.00
# horsepower             95.00
# peakrpm              5200.00
# citympg                24.00
# highwaympg             30.00
# price               10295.00
# dtype: float64

# %%
df.mode()
# Out:
#      car_ID  symbol         CarName fueltype aspiration doorno carbody  \
# 0         1     0.0     peugeot 504      gas        std   four   sedan
# 1         2     NaN  toyota corolla      NaN        NaN    NaN     NaN
# 2         3     NaN   toyota corona      NaN        NaN    NaN     NaN
# 3         4     NaN             NaN      NaN        NaN    NaN     NaN
# 4         5     NaN             NaN      NaN        NaN    NaN     NaN
# ..      ...     ...             ...      ...        ...    ...     ...
# 200     201     NaN             NaN      NaN        NaN    NaN     NaN
# 201     202     NaN             NaN      NaN        NaN    NaN     NaN
# 202     203     NaN             NaN      NaN        NaN    NaN     NaN
# 203     204     NaN             NaN      NaN        NaN    NaN     NaN
# 204     205     NaN             NaN      NaN        NaN    NaN     NaN
#
#     drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# ...

# %%
df.sum()
# Out:
# car_ID                                                          21115
# symbol                                                            171
# CarName             alfa-romero giuliaalfa-romero stelvioalfa-rome...
# fueltype            gasgasgasgasgasgasgasgasgasgasgasgasgasgasgasg...
# aspiration          stdstdstdstdstdstdstdstdturboturbostdstdstdstd...
# doorno              twotwotwofourfourtwofourfourfourtwotwofourtwof...
# carbody             convertibleconvertiblehatchbacksedansedansedan...
# drivewheel          rwdrwdrwdfwd4wdfwdfwdfwdfwd4wdrwdrwdrwdrwdrwdr...
# enginelocation      frontfrontfrontfrontfrontfrontfrontfrontfrontf...
# wheelbase                                                     20245.1
# carlength                                                     35680.1
# carwidth                                                      13511.1
# carheight                                                     11013.6
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symbol', 'CarName', 'fueltype', 'aspiration', 'doorno',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
#to check the duplicate rows
duplicate_rows_df = df[df.duplicated()]
print("Number of duplicated rows: ",duplicate_rows_df.shape)
# Out:
# Number of duplicated rows:  (0, 26)

# %%
df.iloc[0:5]
# Out:
#    car_ID  symbol                   CarName fueltype aspiration doorno  \
# 0       1       3        alfa-romero giulia      gas        std    two
# 1       2       3       alfa-romero stelvio      gas        std    two
# 2       3       1  alfa-romero Quadrifoglio      gas        std    two
# 3       4       2               audi 100 ls      gas        std   four
# 4       5       2                audi 100ls      gas        std   four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
#Renaming the columns
df= df.rename(columns={"symboling":"symbol", "doornumber":"doorno", })
df.head(5)
# Out:
#    car_ID  symbol                   CarName fueltype aspiration doorno  \
# 0       1       3        alfa-romero giulia      gas        std    two
# 1       2       3       alfa-romero stelvio      gas        std    two
# 2       3       1  alfa-romero Quadrifoglio      gas        std    two
# 3       4       2               audi 100 ls      gas        std   four
# 4       5       2                audi 100ls      gas        std   four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df[(df['price'])>44000]
# Out:
#     car_ID  symbol                          CarName fueltype aspiration  \
# 74      75       1  buick regal sport coupe (turbo)      gas        std
#
#    doorno  carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 74    two  hardtop        rwd          front      112.0  ...         304
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 74        mpfi        3.8    3.35              8.0        184     4500
#
#    citympg  highwaympg    price
# 74      14          16  45400.0
#
# [1 rows x 26 columns]

# %%
#Box Plot : used to find outliers in data.
sns.boxplot(x='CarName',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='CarName', ylabel='price'>

# %%
#Barplot: is basically used to aggregate the categorical data according to some methods and by default it’s the mean
sns.barplot(x='CarName',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='CarName', ylabel='price'>

# %%
#Box Plot : used to find outliers in data.
sns.boxplot(x=df['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
#Scatter Plot : are used to observe relationship betwwen variablesand uses
#dots to represent the relationship between them.

sns.scatterplot(x='CarName',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='CarName', ylabel='price'>

# %% [markdown]
# #Updation

# %%
#Countplot: is used to show the counts of obervations in each categorical data bin using bars.
sns.countplot(x='fueltype',data=df)
# Out:
# <AxesSubplot:xlabel='fueltype', ylabel='count'>

# %%
sns.countplot(x='aspiration',data=df)
# Out:
# <AxesSubplot:xlabel='aspiration', ylabel='count'>

# %%
#Pie Plot:is a circular statistical plot that can display only one series of data. 
#The area of the chart is the total percentage of the given data.

labels = ['fueltypes','aspiration']
sizes = [20,30]


fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.show()

# %%
#Distribution plot: is suitable for comparing range and distribution for groups of numeric data.
sns.distplot(df['price'])
# Out:
# C:\Users\Akash Shetty\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
#Box Plot : used to find outliers in data.
sns.boxplot(x=df['horsepower'])
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %%
df[(df['enginesize'])>300]
# Out:
#     car_ID  symbol                          CarName fueltype aspiration  \
# 49      50       0                        jaguar xk      gas        std
# 73      74       0            buick century special      gas        std
# 74      75       1  buick regal sport coupe (turbo)      gas        std
#
#    doorno  carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 49    two    sedan        rwd          front      102.0  ...         326
# 73   four    sedan        rwd          front      120.9  ...         308
# 74    two  hardtop        rwd          front      112.0  ...         304
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 49        mpfi       3.54    2.76             11.5        262     5000
# 73        mpfi       3.80    3.35              8.0        184     4500
# 74        mpfi       3.80    3.35              8.0        184     4500
#
#    citympg  highwaympg    price
# 49      13          17  36000.0
# ...

# %%
#Box Plot : used to find outliers in data.
sns.boxplot(x='carbody',y='enginesize',data=df)
# Out:
# <AxesSubplot:xlabel='carbody', ylabel='enginesize'>

# %%
#Countplot: is used to show the counts of obervations in each categorical data bin using bars.
sns.countplot(x='carbody',data=df)
plt.title('carbody')
plt.show()

# %%
#Countplot: is used to show the counts of obervations in each categorical data bin using bars.
sns.countplot(x='fueltype',data=df)
plt.title('No of Cars having their fueltypes')
plt.show()

# %%
#Barplot: is basically used to aggregate the categorical data according to some methods and by default it’s the mean
#Checking the city mpg
sns.barplot(x='CarName',y='citympg',data=df)
# Out:
# <AxesSubplot:xlabel='CarName', ylabel='citympg'>

# %%
#Barplot: is basically used to aggregate the categorical data according to some methods and by default it’s the mean
#Checking the highwaympg
sns.barplot(x='CarName',y='highwaympg',data=df)
# Out:
# <AxesSubplot:xlabel='CarName', ylabel='highwaympg'>

# %%
#Violin PLot: it shows several quantitative data across one or more categorical varibales

sns.violinplot(x='CarName',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='CarName', ylabel='price'>

# %%
#Histogram plot:used for continous data
df.hist(figsize=(10,20))
# Out:
# array([[<AxesSubplot:title={'center':'car_ID'}>,
#         <AxesSubplot:title={'center':'symbol'}>,
#         <AxesSubplot:title={'center':'wheelbase'}>,
#         <AxesSubplot:title={'center':'carlength'}>],
#        [<AxesSubplot:title={'center':'carwidth'}>,
#         <AxesSubplot:title={'center':'carheight'}>,
#         <AxesSubplot:title={'center':'curbweight'}>,
#         <AxesSubplot:title={'center':'enginesize'}>],
#        [<AxesSubplot:title={'center':'boreratio'}>,
#         <AxesSubplot:title={'center':'stroke'}>,
#         <AxesSubplot:title={'center':'compressionratio'}>,
#         <AxesSubplot:title={'center':'horsepower'}>],
#        [<AxesSubplot:title={'center':'peakrpm'}>,
#         <AxesSubplot:title={'center':'citympg'}>,
#         <AxesSubplot:title={'center':'highwaympg'}>,
#         <AxesSubplot:title={'center':'price'}>]], dtype=object)

# %%
#Pair plots: lets us understand the pairwise relationship between different variables in a dataset
sns.pairplot(df)

# %%
#Heat map: is a plot of rectangular data as a color-encoded matrix and 
#can show the relation between variables including time.
a=df.corr()
sns.heatmap(a)
sns.set(rc = {'figure.figsize':(15,15)})

# %%
sns.heatmap(df.corr(),cmap='tab20',annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),cmap='tab20',annot=True,linewidth=2,linecolor='red')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),cmap='tab20',cbar=False,annot=True,linewidth=2,linecolor='red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # THE END
